# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('dataset.csv')

# %%
data
# Out:
#      sky   air temperature humidity    wind water forecast  enjoy sport
# 0  sunny  warm      normal   strong  strong  warm     same          yes
# 1  sunny  warm        high   strong  strong  warm     same          yes
# 2  rainy  cold        high   strong  strong  warm     same           no
# 3  sunny  warm        high   strong  strong  warm     same          yes

# %%
concepts = np.array(data)[:,:-1]

# %%
concepts
# Out:
# array([['sunny', 'warm', 'normal', 'strong', 'strong', 'warm', 'same'],
#        ['sunny', 'warm', 'high', 'strong', 'strong', 'warm', 'same'],
#        ['rainy', 'cold', 'high', 'strong', 'strong', 'warm', 'same'],
#        ['sunny', 'warm', 'high', 'strong', 'strong', 'warm', 'same']],
#       dtype=object)

# %%
target = np.array(data)[:,-1]

# %%
target
# Out:
# array(['yes', 'yes', 'no', 'yes'], dtype=object)

# %%
def train(con, tar): 
    for i,val in enumerate(tar):
        if val =='yes':
            specific_h=con[i].copy()
            break
    for i, val in enumerate(con):
        if tar[i]=='yes':
            for x in range(len(specific_h)):
                if val[x] !=specific_h[x]:
                    specific_h[x]='?'
                else:
                    pass
    return specific_h

# %%
print(train(concepts,target))
# Out:
# ['sunny' 'warm' '?' 'strong' 'strong' 'warm' 'same']
